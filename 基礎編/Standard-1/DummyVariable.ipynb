# %% [markdown]
# 課題テーマ：　ダミー変数を使ったモデル \
# 簡単な線形回帰モデル(重回帰モデル)を試す \
# 残業時間(overtime)と部署(section)の関係を分析する
#
# <課題>
# 1. 以下のライブラリの読み込みを行なってください。 \
# Numpy, Pandas, Matplotlib, Seaborn, japanize-matplotlib
#
#
# 2. sklearnのlinear_modelにある、LinearRegressionの読み込みをしてください。
#
#
# 3. dataディレクトリ配下にある、StaffOvertime.csvを読み込みデータフレームに格納し、先頭の数行を確認してください。
#
#
# 4. 部署ごとの残業時間の差異を図表で確認してください。この際に、何を使えばいいか検討してください。
#
#
# 5. 部署毎の統計要約量を算出してください。
#
#
# 6. ダミー変数、ワンホットエンコーディングについて調べ、理解をしてください。
#
#
# 7. pandasの```get_dummies()```を使い、カテゴリ変数である部署をダミー変数化してください。また、ダミー変数化したデータフレームは新たなものとして格納してください。
#
#
# 8. sklearnのLienarRegressionを使い、目的変数を残業時間、説明変数をダミー変数化したものを使用し、モデルの学習を行なってください。
#
#
# 9. 学習したモデルの回帰係数、切片、決定係数を表示してください。
#
#
# 10. 学習したモデルの回帰係数、切片を使うと、今回学習したモデルの回帰式はどうなりますか。
