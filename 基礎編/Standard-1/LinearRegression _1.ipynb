# %% [markdown]
# <課題テーマ>\
# 簡単な線形回帰モデル(単回帰モデル)を試す \
# 勤続年数によって残業時間はどの程度増えるか、もしくは減るか
#
#
# <課題>
# 1. 以下のライブラリの読み込みを行なってください。 \
# Numpy, Pandas, Matplotlib, Seaborn, japanize-matplotlib
#
#
# 2. sklearnのlinear_modelにある、LinearRegressionの読み込みをしてください。
#
#
# 3. dataディレクトリ配下にある、StaffOvertime.csvを読み込みデータフレームに格納してください。
#   - ID: 社員ID
#   - section: 所属部署
#   - tenure: 勤続年数
#   - overtime: 残業時間
#
#
# 4. データフレームの先頭の数行を確認してください。
#
#
# 5. 量的変数の要約統計量を算出、表示してください。
#
#
# 6. カテゴリ変数のユニークな要素の個数を表示してください。
#
#
# 7. それぞれのデータ型を確認してください。
#
#
# 8. 今回の目的変数、説明変数についてそれぞれヒストグラムを描画する。
#
#
# 9. 今回の目的変数、説明変数について散布図を描画する。
#
#
# 10. 単回帰モデルはどういうものか確認してください。（どういう数式で表されるか確認すること）
#
#
# 11. sklearnのLienarRegressionを使い、今回の目的変数、説明変数を用いて、モデルの学習を行なってください。
#
#
# 12. 学習したモデルの回帰係数、切片、決定係数を表示してください。
#
#
# 13. 学習したモデルに説明変数をいれ、予測値を算出してください。
#
#
# 14. 目的変数、説明変数について散布図を描画し、散布図内に今回学習した回帰式線を併せて描画してください。
